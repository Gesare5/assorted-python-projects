# %%
# Automation script to find and update all necessary imports

import os
import re

#Create a list of file names in a given directory
regex_pattern = r'^(\.{2}\/)+'

def find_and_replace(line):
    replacement = re.sub(pattern=regex_pattern, repl='', string=line)
    return replacement

file_names = []
for root, dirs, files in os.walk('./sample_folder', topdown=True):
    for name in files:
        name = os.path.join(root, name)
        file_names.append(name)


# print(file_names)
for name in file_names:
    with open(name, 'r' ) as file:  
        lines = file.readlines()
        for line in lines:
            find_and_replace(line)



# blue = '../models/AccountUsersAccess'
# match = re.search(regex_pattern, blue) 
# print(match)
# print(replacement)

    # print('-----------------------')
    # for name in dirs:
