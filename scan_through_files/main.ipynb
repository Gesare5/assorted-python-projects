# %%
import os

# %%
for root, dirs, files in os.walk('../', topdown=True):
    for name in files:
        print(name)
        
    print('-----------------------')
    # for name in dirs:
    #     print(name)
# Out:
# MOCK_DATA.csv
# user_emails.csv
# wordCloud.py
# reverse_integer.ipynb
# updated_user_emails.csv
# firstnotebook.ipynb
# directory.py
# regex.py
# read.csv
# working_with_regex.py
# number_guesser.py
# quiz_game.py
# -----------------------
# script.py
# -----------------------
# dataframe_data_structure.ipynb
# -----------------------
# ic_polygon.png
# matrix.ipynb
# einstein.jpg
# -----------------------
# userRegistration.csv
# UI.py
# -----------------------
# sample_data.csv
# countries.csv
# data_analysis.ipynb
# data+visualization+with+python.ipynb
# -----------------------
# compound.ipynb
# tax_chart.ipynb
# -----------------------
# main.py
# main.ipynb
# -----------------------
# syslog.log
# user_emails.csv
# loganalysis.py
# csv_to_html.py
# ticky_check.py
# -----------------------
# -----------------------
# main.py
# -----------------------
# -----------------------
# survey_results_public.csv
# modified.json
# dataframes.ipynb
# so_survey_2022.pdf
# read_write_different_files.ipynb
# datetime_timeseries.ipynb
# README_2022.txt
# survey_results_schema.csv
# modified.tsv
# ETH_1h.csv
# modified.csv
# -----------------------
# datagen.py
# views.csv
# data.csv
# charts.ipynb
# datas.csv
# -----------------------

# %%
for root, dirs, files in os.walk('../', topdown=True):
    for name in files:
        new = os.path.join(root, name)
        with open('data.txt', 'a') as file:
            file.write(new)
            file.write('\n')
        print(root)
        print(os.path.join(root, name))

    # for name in dirs:
    #     print(os.path.join(root, name))    
        
    print('-----------------------')
    # for name in dirs:
    #     print(name)
# Out:
# ../
# ../MOCK_DATA.csv
# ../
# ../user_emails.csv
# ../
# ../wordCloud.py
# ../
# ../reverse_integer.ipynb
# ../
# ../updated_user_emails.csv
# ../
# ../firstnotebook.ipynb
# ../
# ../directory.py
# ../
# ../regex.py
# ../
# ../read.csv
# ../
# ../working_with_regex.py
# ../
# ../number_guesser.py
# ../
# ../quiz_game.py
# -----------------------
# ../PythonPrograms
# ../PythonPrograms/script.py
# -----------------------
# ../dsintro
# ../dsintro/dataframe_data_structure.ipynb
# -----------------------
# ../prewitt
# ../prewitt/ic_polygon.png
# ../prewitt
# ../prewitt/matrix.ipynb
# ../prewitt
# ../prewitt/einstein.jpg
# -----------------------
# ../store_management
# ../store_management/userRegistration.csv
# ../store_management
# ../store_management/UI.py
# -----------------------
# ../csdojo_ds_intro
# ../csdojo_ds_intro/sample_data.csv
# ../csdojo_ds_intro
# ../csdojo_ds_intro/countries.csv
# ../csdojo_ds_intro
# ../csdojo_ds_intro/data_analysis.ipynb
# ../csdojo_ds_intro
# ../csdojo_ds_intro/data+visualization+with+python.ipynb
# -----------------------
# ../tax
# ../tax/compound.ipynb
# ../tax
# ../tax/tax_chart.ipynb
# -----------------------
# ../scan through files
# ../scan through files/main.py
# ../scan through files
# ../scan through files/main.ipynb
# ../scan through files
# ../scan through files/data.txt
# -----------------------
# ../loganalysis
# ../loganalysis/syslog.log
# ../loganalysis
# ../loganalysis/user_emails.csv
# ../loganalysis
# ../loganalysis/loganalysis.py
# ../loganalysis
# ../loganalysis/csv_to_html.py
# ../loganalysis
# ../loganalysis/ticky_check.py
# -----------------------
# -----------------------
# ../blackjack
# ../blackjack/main.py
# -----------------------
# -----------------------
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/survey_results_public.csv
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/modified.json
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/dataframes.ipynb
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/so_survey_2022.pdf
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/read_write_different_files.ipynb
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/datetime_timeseries.ipynb
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/README_2022.txt
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/survey_results_schema.csv
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/modified.tsv
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/ETH_1h.csv
# ../coreyshafer/Pandas
# ../coreyshafer/Pandas/modified.csv
# -----------------------
# ../coreyshafer/Matplotlib
# ../coreyshafer/Matplotlib/datagen.py
# ../coreyshafer/Matplotlib
# ../coreyshafer/Matplotlib/views.csv
# ../coreyshafer/Matplotlib
# ../coreyshafer/Matplotlib/data.csv
# ../coreyshafer/Matplotlib
# ../coreyshafer/Matplotlib/charts.ipynb
# ../coreyshafer/Matplotlib
# ../coreyshafer/Matplotlib/datas.csv
# -----------------------

# %%
# AVERAGE LINES IN A DIRECTORY
import os 

path_to_directory = './sample_directory'

def get_path_list(main_path):
    path_list = []
    for root, dirs, files in os.walk(main_path, topdown=True):
        for name in files:
            path_list.append(os.path.join(root, name))
    return path_list



path_list = get_path_list(path_to_directory)
# Out:
# 34
